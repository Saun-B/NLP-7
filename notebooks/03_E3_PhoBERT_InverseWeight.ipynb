# %% [markdown]
# # E3 — PhoBERT fine-tuning — INVERSE-FREQUENCY class weight
#
# **Vietnamese Punctuation Restoration · Notebook 3 / 4**
#
# > **Cách chạy:** mở notebook này và chạy **tuần tự từ trên xuống dưới, không bỏ
# > cell nào**. Điều kiện tiên quyết: đã chạy
# > `python scripts/run_data_pipeline.py` thành công.
# >
# > **Notebook chỉ đọc `train.jsonl` và `validation.jsonl`.**
# > `test.jsonl` không được nạp, không được đánh giá, không được nhìn.
# >
# > Toàn bộ code huấn luyện nằm trong `src/`; notebook chỉ đóng vai trò điều phối
# > và giải thích.
#
#
# # 1. Experiment Overview
#
# **E3 = E2 + class weight nghịch đảo tần suất.**
#
# Bài toán và mô hình giống hệt E2 (`vinai/phobert-base-v2`, 4 nhãn, nhãn nằm sau
# từ). Khác biệt duy nhất nằm ở **hàm mất mát**.
#
# **Ý tưởng.** Tập train mất cân bằng nặng:
#
# | nhãn | số token | tỉ lệ | trọng số inverse |
# |----------|-------------|--------|------------------|
# | `O` | 4,500,812 | 91.10% | 0.274 |
# | `COMMA` | 228,032 | 4.62% | 5.416 |
# | `PERIOD` | 184,186 | 3.73% | 6.706 |
# | `QUESTION` | 27,448 | 0.56% | **45.0** |
#
# Công thức:
#
# $$w_c = \frac{N_{\text{train}}}{C \times n_c}$$
#
# với $N_{\text{train}}$ = tổng số token train, $C = 4$ số lớp, $n_c$ = số token
# của lớp $c$. Kết quả: một lỗi trên `QUESTION` bị phạt nặng hơn ~164 lần so với
# một lỗi trên `O`.
#
# **Kỳ vọng và rủi ro.** Kỳ vọng: recall của `QUESTION` và `PERIOD` tăng mạnh.
# Rủi ro: mô hình trở nên "hăng" quá mức — dự đoán dấu câu ở những chỗ không có,
# làm **precision tụt** và kéo F1 xuống. Trọng số 45× là rất lớn; đây đúng là
# điều thí nghiệm cần kiểm chứng bằng số liệu chứ không phải bằng phỏng đoán.
# E4 sẽ thử phương án dịu hơn (căn bậc hai).
#
# **Nguồn trọng số.** Đọc từ `outputs/data/class_weights.json`, được tính **chỉ
# từ tập TRAIN**. Hàm `load_class_weights()` sẽ báo lỗi nếu file ghi nguồn khác
# `train` — dùng thống kê của validation/test để tạo loss là rò rỉ thông tin
# đánh giá vào quá trình huấn luyện.
#
# > ⚠️ **Notebook này KHÔNG bao giờ đọc `test.jsonl`.**

# %%
import os, sys, json, time
from pathlib import Path

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
assert (PROJECT_ROOT / "src").exists(), f"Cannot locate the repo root from {Path.cwd()}"
os.chdir(PROJECT_ROOT)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import torch
import pandas as pd


from src.data.constants import (
    LABELS, LABEL2ID, PUNCTUATION_LABELS, MONITOR_METRIC,
    PROCESSED_FILES, OUTPUT_DATA_DIR, CHECKPOINT_DIR, EXPERIMENT_DIR, SEED,
)
from src.data.dataset import load_examples
from src.evaluation.evaluator import predict_word_labels, sample_predictions
from src.evaluation.metrics import format_metrics_table
from src.models.factory import load_model_from_checkpoint
from src.training.seed import set_seed
from src.utils.environment import collect_environment, format_environment
from src.utils.io import read_json, read_yaml
from src.utils.logging_utils import configure_stdout_utf8

configure_stdout_utf8()

EXPERIMENT_ID = "E3"
CONFIG_PATH   = PROJECT_ROOT / "configs" / "e3_phobert_inverse.yaml"

print(f"Project root : {PROJECT_ROOT}")
print(f"Experiment   : {EXPERIMENT_ID}")
print(f"Config       : {CONFIG_PATH.relative_to(PROJECT_ROOT)}\n")
print(format_environment())
# Out:
# Project root : <USER_HOME>/Documents\GitHub\NLPgrSix7
# Experiment   : E3
# Config       : configs\e3_phobert_inverse.yaml
#
# Python version      : 3.12.4
# Platform            : Windows-11-10.0.26100-SP0
# PyTorch version     : 2.13.0+cu126
# CUDA available      : True
# CUDA runtime        : 12.6
# GPU name            : NVIDIA GeForce RTX 4060 Laptop GPU
# GPU memory (GB)     : 8.0
# Transformers version: 5.14.1
# NumPy version       : 2.5.1

# %% [markdown]
# # 2. Dataset
#
# **Nguồn:** [JointCapPunc](https://github.com/ductho9799/JointCapPunc) (Apache-2.0),
# ghim ở commit `ee258cae0e95e64245428d59ebbb030280fcebec`.
#
# **Split chính thức được giữ nguyên tuyệt đối:**
#
# | file gốc | split của đồ án | dùng trong notebook này |
# |---|---|---|
# | `train.txt` | `train` | ✅ huấn luyện |
# | `dev.txt` | `validation` | ✅ đánh giá + chọn checkpoint |
# | `test.txt` | `test` | ❌ **không đụng đến** — để dành cho Phase 2 |
#
# Không gộp rồi chia lại ngẫu nhiên, không chuyển ví dụ giữa các split.
#
# **Dữ liệu đã qua pipeline** (`scripts/run_data_pipeline.py`): parse nghiêm ngặt →
# chuẩn hoá Unicode NFC (giữ nguyên dấu thanh) → ánh xạ `QMARK → QUESTION` →
# cắt đoạn ≤150 từ ưu tiên tại `PERIOD`/`QUESTION` → khử trùng lặp trong từng
# split → kiểm tra → thống kê.
#
# **Hash dữ liệu.** Mỗi split có `content_sha256` riêng, được chép vào
# `outputs/experiments/<E>/data_hashes.json` và vào metadata của checkpoint. Nhờ
# đó luôn chứng minh được checkpoint này được huấn luyện trên đúng bộ dữ liệu nào.

# %%
config = read_yaml(CONFIG_PATH)


data_cfg = config["data"]
assert "test" not in json.dumps(data_cfg), "test split must not appear in the training config"
print("Files this notebook is allowed to read:")
print("  train      :", data_cfg["train_file"])
print("  validation :", data_cfg["validation_file"])
print("  test       : NOT LOADED  <-- reserved for Phase 2\n")


data_hashes = read_json(OUTPUT_DATA_DIR / "data_hashes.json")
for split in ("train", "validation"):
    h = data_hashes[split]
    print(f"  {split:<11} {h['num_examples']:>7,} examples  "
          f"{h['num_tokens']:>11,} tokens  content_sha256={h['content_sha256'][:16]}…")

set_seed(int(config["training"]["seed"]))

t0 = time.time()
train_examples      = load_examples(PROCESSED_FILES["train"])
validation_examples = load_examples(PROCESSED_FILES["validation"])
print(f"\nLoaded {len(train_examples):,} train / {len(validation_examples):,} validation "
      f"examples in {time.time() - t0:.1f}s")
# Out:
# Files this notebook is allowed to read:
#   train      : data/processed/train.jsonl
#   validation : data/processed/validation.jsonl
#   test       : NOT LOADED  <-- reserved for Phase 2
#
#   train        38,066 examples    4,940,478 tokens  content_sha256=138983bc2761546f…
#   validation   15,227 examples    1,977,406 tokens  content_sha256=874133954b31fbfd…
# 2026-08-09 22:33:56 | INFO    | src.training.seed | Seed set to 42 (deterministic=False)
# 2026-08-09 22:33:59 | INFO    | src.data.dataset | Loaded 38066 examples from train.jsonl
# 2026-08-09 22:34:00 | INFO    | src.data.dataset | Loaded 15227 examples from validation.jsonl
#
# Loaded 38,066 train / 15,227 validation examples in 3.4s

# %%
stats = read_json(OUTPUT_DATA_DIR / "data_statistics.json")

rows = []
for split in ("train", "validation"):
    s = stats["splits"][split]
    row = {"split": split, "examples": s["num_examples"], "tokens": s["num_tokens"],
           "mean_len": round(s["mean_length"], 1), "max_len": s["max_length"]}
    for lab in LABELS:
        row[f"%{lab}"] = round(100 * s["label_ratios"][lab], 3)
    rows.append(row)
display(pd.DataFrame(rows).set_index("split"))

ex = train_examples[0]
print("\nVí dụ một dòng dữ liệu (10 từ đầu):")
for tok, lab in list(zip(ex.tokens, ex.labels))[:10]:
    print(f"   {tok:<14} -> {lab}")
print(f"   … tổng cộng {len(ex.tokens)} từ, id={ex.id}, source_id={ex.source_id}")
# Out:
#             examples   tokens  mean_len  max_len      %O  %COMMA  %PERIOD  \
# split
# train          38066  4940478     129.8      150  91.101   4.616    3.728
# validation     15227  1977406     129.9      150  91.058   4.643    3.743
#
#             %QUESTION
# split
# train           0.556
# validation      0.556
# Ví dụ một dòng dữ liệu (10 từ đầu):
#    hơn            -> O
#    2              -> O
#    tháng          -> O
#    qua            -> O
#    amidan         -> O
#    khẩu           -> O
#    cái            -> O
#    của            -> O
#    em             -> O
#    có             -> O
#    … tổng cộng 93 từ, id=train_000001, source_id=train_seg_000001

# %% [markdown]
# # 3. Model
#
# **`vinai/phobert-base-v2` + đầu ra token classification**
# (`src/models/phobert.py`):
#
# ```
# input_ids  (batch, ≤192 subword)
#     │
#     ▼
# RoBERTa encoder  (12 layer, hidden 768, 12 attention head)   ← đã tiền huấn luyện
#     │                                          (batch, seq, 768)
#     ▼
# Dropout
#     │
#     ▼
# Linear(768 → 4)                                ← khởi tạo ngẫu nhiên, học từ đầu
#     │
#     ▼
# logits (batch, seq, 4)
# ```
#
# Tổng cộng ~135 triệu tham số, **tất cả đều được fine-tune** (không đóng băng
# lớp nào).
#
# **Revision được ghim (pinned).** Model không chỉ được gọi theo tên mà theo đúng
# commit trên Hugging Face:
#
# ```
# vinai/phobert-base-v2 @ fb76b7e1f77fa19bc4870e2ad956876f7c81c53f
# ```
#
# Điều này bắt buộc vì E2/E3/E4 phải xuất phát từ **cùng một bộ trọng số ban
# đầu**. Nếu Hugging Face cập nhật model, ba thí nghiệm sẽ không còn so sánh được
# với nhau và toàn bộ kết luận về class weight sẽ mất giá trị.
#
# **Vì sao PhoBERT chứ không phải mBERT/XLM-R?** PhoBERT được tiền huấn luyện
# riêng cho tiếng Việt với bộ từ vựng BPE xây trên âm tiết tiếng Việt, nên một âm
# tiết thường chỉ tách thành 1 subword. Các model đa ngữ tách tiếng Việt vụn hơn
# nhiều, làm chuỗi dài ra và việc gán nhãn theo từ khó hơn.
#
# **Model trả về logits thô.** Wrapper của chúng ta *không* truyền `labels` vào
# Hugging Face, vì mỗi thí nghiệm cần một hàm loss khác nhau (có/không class
# weight). Loss được tính trong trainer.

# %% [markdown]
# # 4. Tokenization / Vocabulary
#
# Đây là phần tinh tế nhất của toàn bộ pipeline PhoBERT.
#
# **Vấn đề.** PhoBERT dùng BPE, một *từ vựng* (lexical word) có thể bị tách thành
# nhiều *subword*. Nhưng nhãn của ta gắn với **từ**, và mô tả dấu câu đứng **sau
# cả từ đó**. Vậy nhãn phải đặt ở đâu?
#
# **Quy tắc: nhãn đặt tại SUBWORD CUỐI CÙNG của từ.**
# Mọi vị trí còn lại được gán `IGNORE_INDEX = -100`:
#
# ```
# từ:        [ hoàn ]  [ thành ]  [   chưa   ]
# subword:    ho@@ àn   thành      ch@@  ưa
# nhãn:       -100  O   PERIOD     -100  QUESTION
#                   ▲   ▲                 ▲
#                   └───┴─── mỗi từ được giám sát ĐÚNG MỘT LẦN, tại subword cuối
# ```
#
# `-100` cũng được gán cho `<s>`, `</s>` và các vị trí padding.
#
# **Vì sao là subword cuối chứ không phải subword đầu?** Vì dấu câu đứng *sau* từ.
# Subword cuối là vị trí gần dấu câu nhất và là vị trí đã "đọc" xong toàn bộ từ.
# Nếu đặt nhãn ở subword đầu, mô hình phải dự đoán dấu câu trước khi đọc hết từ.
#
# **Bất biến được kiểm tra bằng test tự động** (`tests/test_alignment.py`):
# mỗi từ được giám sát đúng một lần, không từ nào bị mất, thứ tự không đổi.
#
# **Cửa sổ 192 subword.** Một ví dụ có tối đa 150 từ; tiếng Việt qua PhoBERT
# thường ~1.05 subword/từ nên hầu hết vừa trong 192. Khi vượt quá,
# `align_words_to_subwords()` **cắt thành nhiều cửa sổ tại ranh giới từ** — không
# bao giờ truncate âm thầm. Một từ không bao giờ bị chia đôi giữa hai cửa sổ, nên
# gộp dự đoán của các cửa sổ lại là khôi phục đúng chuỗi nhãn đầy đủ.
#
# **Tối ưu tốc độ.** `PhoBERTEncoder` nhớ (memoize) kết quả tách subword theo từ.
# Corpus chỉ có ~31k từ khác nhau trên hàng triệu token, nên sau vài nghìn ví dụ
# việc tokenize gần như chỉ còn là tra từ điển.

# %%
from src.data.constants import IGNORE_INDEX, PHOBERT_MAX_LENGTH
from src.data.dataset import PhoBERTEncoder
from src.models.phobert import load_phobert_tokenizer

tokenizer = load_phobert_tokenizer(config["model"]["name"], config["model"]["revision"])
print(f"Tokenizer     : {type(tokenizer).__name__}")
print(f"Model         : {config['model']['name']}")
print(f"Revision      : {config['model']['revision']}")
print(f"Vocab size    : {tokenizer.vocab_size:,}")
print(f"Window length : {config['model']['max_length']} subwords\n")

encoder = PhoBERTEncoder(tokenizer, max_length=int(config["model"]["max_length"]))


from src.data.schema import Example
demo = Example(
    id="demo", source_split="train", source_id="demo_seg", chunk_index=0,
    tokens="bạn đã hoàn thành bài tập chưa ngày mai chúng ta nộp bài".split(),
    labels=["O"] * 6 + ["QUESTION"] + ["O"] * 5 + ["PERIOD"],
)
(window,) = encoder.encode_example(demo)
id2label = {v: k for k, v in LABEL2ID.items()}

print(f"{'pos':>4}  {'subword':<14}{'label':<10}{'thuộc từ':<10}")
print("-" * 44)
for pos, (sid, lab, widx) in enumerate(zip(window.input_ids, window.labels, window.word_index)):
    piece = tokenizer.convert_ids_to_tokens([sid])[0]
    label_txt = "IGNORE(-100)" if lab == IGNORE_INDEX else f"{id2label[lab]}"
    word_txt  = "-" if widx < 0 else f"{widx} ({demo.tokens[widx]})"
    print(f"{pos:>4}  {piece:<14}{label_txt:<14}{word_txt}")

supervised = [w for w in window.word_index if w >= 0]
print(f"\nSố từ = {len(demo.tokens)} | số vị trí được giám sát = {len(supervised)} "
      f"| khớp: {supervised == list(range(len(demo.tokens)))}")
# Out:
# 2026-08-09 22:34:02 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/vinai/phobert-base-v2/resolve/fb76b7e1f77fa19bc4870e2ad956876f7c81c53f/tokenizer_config.json "HTTP/1.1 404 Not Found"
# 2026-08-09 22:34:02 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/vinai/phobert-base-v2/resolve/fb76b7e1f77fa19bc4870e2ad956876f7c81c53f/tokenizer_config.json "HTTP/1.1 404 Not Found"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-08-09 22:34:02 | WARNING | huggingface_hub.utils._http | Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-08-09 22:34:03 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/models/vinai/phobert-base-v2/tree/fb76b7e1f77fa19bc4870e2ad956876f7c81c53f/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-08-09 22:34:03 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/models/vinai/phobert-base-v2/tree/fb76b7e1f77fa19bc4870e2ad956876f7c81c53f?recursive=true&expand=false "HTTP/1.1 200 OK"
# Tokenizer     : PhobertTokenizer
# Model         : vinai/phobert-base-v2
# Revision      : fb76b7e1f77fa19bc4870e2ad956876f7c81c53f
# Vocab size    : 64,000
# Window length : 192 subwords
#
#  pos  subword       label     thuộc từ
# --------------------------------------------
#    0  <s>           IGNORE(-100)  -
#    1  bạn           O             0 (bạn)
#    2  đã            O             1 (đã)
#    3  hoàn          O             2 (hoàn)
#    4  thành         O             3 (thành)
#    5  bài           O             4 (bài)
#    6  tập           O             5 (tập)
#    7  chưa          QUESTION      6 (chưa)
#    8  ngày          O             7 (ngày)
#    9  mai           O             8 (mai)
#   10  chúng         O             9 (chúng)
#   11  ta            O             10 (ta)
#   12  nộp           O             11 (nộp)
#   13  bài           PERIOD        12 (bài)
#   14  </s>          IGNORE(-100)  -
#
# Số từ = 13 | số vị trí được giám sát = 13 | khớp: True

# %% [markdown]
# # 5. Loss Strategy
#
# **`CrossEntropyLoss(weight=inverse_frequency_weights, ignore_index=-100)`**
#
# ```python
# w_c = total_train_tokens / (4 * count_c)
# loss_fn = nn.CrossEntropyLoss(weight=torch.tensor(w), ignore_index=-100)
# ```
#
# Trọng số được nạp từ `outputs/data/class_weights.json`, **tính từ tập TRAIN**.
# Hàm `load_class_weights()` kiểm tra trường `source_split` và sẽ *báo lỗi* nếu
# trọng số không đến từ train — dùng thống kê của validation hoặc test để tạo
# loss chính là rò rỉ thông tin đánh giá.
#
# **Cơ chế hoạt động.** Trong CrossEntropyLoss có trọng số, đóng góp của một token
# thuộc lớp $c$ được nhân với $w_c$. Vì `QUESTION` có $w \approx 45$ còn `O` có
# $w \approx 0.27$, một lỗi trên `QUESTION` "đắt" hơn ~164 lần. Gradient vì thế
# bị đẩy mạnh về phía các lớp hiếm.
#
# **Điều cần theo dõi.** Kỳ vọng recall của `QUESTION`/`PERIOD` tăng rõ. Nhưng hãy
# nhìn cả **precision**: nếu mô hình bắt đầu rắc dấu câu ở những chỗ không có,
# precision sẽ tụt và F1 có thể còn thấp hơn E2. Kết luận phải dựa trên
# Punctuation Macro-F1, không dựa trên riêng recall.

# %%
from src.training.losses import get_class_weight_vector, load_class_weights

class_weights_blob = load_class_weights()
weight_mode        = config["loss"]["weight_mode"]
weight_vector      = get_class_weight_vector(weight_mode, class_weights=class_weights_blob)

print(f"weight_mode  : {weight_mode}")
print(f"nguồn trọng số: {class_weights_blob['source_split']} split "
      f"({class_weights_blob['total_train_tokens']:,} tokens)\n")

table = []
for i, lab in enumerate(LABELS):
    table.append({
        "label": lab,
        "train_count": class_weights_blob["counts"][lab],
        "train_share_%": round(100 * class_weights_blob["frequencies"][lab], 3),
        "inverse": round(class_weights_blob["inverse"][lab], 4),
        "sqrt_inverse": round(class_weights_blob["sqrt_inverse"][lab], 4),
        "USED HERE": "1.0 (none)" if weight_vector is None else round(weight_vector[i], 4),
    })
display(pd.DataFrame(table).set_index("label"))
# Out:
# weight_mode  : inverse
# nguồn trọng số: train split (4,940,478 tokens)
#           train_count  train_share_%  inverse  sqrt_inverse  USED HERE
# label
# O             4500812         91.101   0.2744        0.5239     0.2744
# COMMA          228032          4.616   5.4164        2.3273     5.4164
# PERIOD         184186          3.728   6.7058        2.5896     6.7058
# QUESTION        27448          0.556  44.9985        6.7081    44.9985

# %% [markdown]
# # 6. Hyperparameters
#
# Tất cả tham số đọc từ `configs/e3_phobert_inverse.yaml` — notebook không hardcode số
# nào. Muốn đổi thí nghiệm thì sửa file config, không sửa notebook.
#
# | tham số | giá trị | ghi chú |
# |---|---|---|
# | epochs | 5 | fine-tuning cần ít lượt |
# | batch size (train) | 4 | vừa GPU 8GB ở độ dài 192 |
# | gradient accumulation | 4 | → batch hiệu dụng ≈ **16** |
# | batch size (eval) | 8 | |
# | optimizer | AdamW | bias và LayerNorm **không** bị weight decay |
# | learning rate | 3e-5 | chuẩn cho fine-tuning BERT |
# | weight decay | 1e-2 | |
# | warmup ratio | 0.10 | 10% số optimizer step đầu |
# | scheduler | linear warmup → linear decay về 0 | cập nhật mỗi **optimizer step** |
# | gradient clipping | 1.0 | unscale trước khi clip khi dùng fp16 |
# | loss | CrossEntropyLoss, `weight_mode = inverse` | **điểm khác biệt duy nhất giữa E2/E3/E4** |
# | max_length | 192 subword | dài hơn thì cắt cửa sổ tại ranh giới từ |
# | seed | 42 | random, numpy, torch, CUDA, DataLoader |
# | mixed precision | fp16 trên CUDA, tự động lùi về fp32 nếu không có GPU | |
# | metric chọn checkpoint | validation Punctuation Macro-F1 | |
#
# **Thời gian huấn luyện dự kiến:** khoảng 1.5–3 giờ trên GPU 8GB (5 epoch × ~38k window).

# %%
def flatten(prefix, obj, out):
    for k, v in obj.items():
        key = f"{prefix}.{k}" if prefix else k
        if isinstance(v, dict):
            flatten(key, v, out)
        else:
            out.append({"parameter": key, "value": v})
    return out

display(pd.DataFrame(flatten("", config, [])).set_index("parameter"))
# Out:
#                                                                                       value
# parameter
# experiment.id                                                                            E3
# experiment.name                                   PhoBERT — inverse-frequency class weights
# experiment.description                    Same setup as E2, but CrossEntropyLoss is weig...
# model.type                                                                          phobert
# model.name                                                            vinai/phobert-base-v2
# model.revision                                     fb76b7e1f77fa19bc4870e2ad956876f7c81c53f
# model.num_labels                                                                          4
# model.max_length                                                                        192
# model.dropout                                                                          None
# data.train_file                                                  data/processed/train.jsonl
# data.validation_file                                        data/processed/validation.jsonl
# data.max_words                                                                          150
# loss.type                                                                     cross_entropy
# loss.weight_mode                                                                    inverse
# loss.ignore_index                                                                      -100
# optimizer.name                                                                        adamw
# optimizer.learning_rate                                                             0.00003
# optimizer.weight_decay                                                                 0.01
# optimizer.betas                                                                [0.9, 0.999]
# optimizer.eps                                                                           0.0
# optimizer.no_decay_on_bias_and_layernorm                                               True
# scheduler.name                                                                linear_warmup
# scheduler.warmup_ratio                                                                  0.1
# training.epochs                                                                           5
# training.train_batch_size                                                                 4
# training.gradient_accumulation_steps                                                      4
# training.eval_batch_size                                                                  8
# training.max_grad_norm                                                                  1.0
# training.seed                                                                            42
# training.num_workers                                                                      0
# training.fp16                                                                          True
# training.deterministic                                                                False
# training.monitor_metric                                                punctuation_macro_f1
# training.early_stopping_patience                                                       None
# training.log_every_n_steps                                                              500
# paths.checkpoint_dir                                                 outputs/checkpoints/E3
# paths.experiment_dir                                                 outputs/experiments/E3

# %% [markdown]
# # 7. Training
#
# Vòng lặp huấn luyện (`src/training/trainer_phobert.py`) cho mỗi epoch:
#
# 1. `model.train()`;
# 2. với từng micro-batch (4 cửa sổ):
#    - forward trong `autocast(float16)` nếu có CUDA,
#    - tính loss ở fp32 để tránh tràn số,
#    - `loss / 4` rồi `backward()` — chia cho số bước tích luỹ để độ lớn gradient
#      đúng bằng batch 16 thật;
# 3. **cứ 4 micro-batch** thì:
#    - unscale gradient (fp16), clip norm về 1.0,
#    - `optimizer.step()`, `scheduler.step()`, `zero_grad()`;
# 4. nếu epoch kết thúc giữa chừng một chu kỳ tích luỹ, phần gradient còn lại
#    **vẫn được áp dụng** — không có batch nào bị bỏ phí;
# 5. hết epoch → validation (mục 8) → ghi checkpoint nếu tốt hơn.
#
# Vì sao batch 4 + tích luỹ 4 chứ không phải batch 16 thẳng? Vì batch 16 ở độ dài
# 192 subword không vừa VRAM 8GB. Tích luỹ gradient cho *cùng* độ lớn cập nhật
# với chi phí bộ nhớ của batch 4.
#
# **Ba thứ được ghi lại sau mỗi epoch:** một dòng trong `training_history.csv`
# (loss, learning rate, thời gian, toàn bộ metric validation), quyết định
# checkpoint, và log in ra màn hình.

# %%
from src.training.trainer_phobert import build_phobert_trainer

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
if device.type == "cuda":
    print(f"GPU   : {torch.cuda.get_device_name(0)} "
          f"({torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB)")

trainer, tokenizer = build_phobert_trainer(
    config,
    train_examples,
    validation_examples,
    tokenizer=tokenizer,
    data_hashes=data_hashes,
    device=device,
)

n_params = sum(p_.numel() for p_ in trainer.model.parameters())
accum    = trainer.gradient_accumulation_steps
print(f"\nModel parameters      : {n_params:,} ({n_params / 1e6:.1f}M)")
print(f"Train windows         : {len(trainer.train_loader.dataset):,}")
print(f"Validation windows    : {len(trainer.validation_loader.dataset):,}")
print(f"Micro-batches / epoch : {len(trainer.train_loader):,}")
print(f"Optimizer steps/epoch : {len(trainer.train_loader) // accum:,} "
      f"(accumulation = {accum}, effective batch = {trainer.train_loader.batch_size * accum})")
print(f"Mixed precision (fp16): {trainer.use_amp}")
# Out:
# Device: cuda
# GPU   : NVIDIA GeForce RTX 4060 Laptop GPU (8.0 GB)
# 2026-08-09 22:34:03 | INFO    | src.training.seed | Seed set to 42 (deterministic=False)
# 2026-08-09 22:34:06 | INFO    | src.data.dataset | Encoded 20000/38066 examples
# 2026-08-09 22:34:08 | INFO    | src.data.dataset | PhoBERT dataset ready: {'num_examples': 38066, 'num_windows': 38111, 'num_words': 4940478, 'num_subwords': 5207406, 'windows_per_example': 1.0012, 'subwords_per_word': 1.054, 'examples_split_into_multiple_windows': 45, 'max_window_length': 192}
# 2026-08-09 22:34:10 | INFO    | src.data.dataset | PhoBERT dataset ready: {'num_examples': 15227, 'num_windows': 15243, 'num_words': 1977406, 'num_subwords': 2083427, 'windows_per_example': 1.0011, 'subwords_per_word': 1.0536, 'examples_split_into_multiple_windows': 16, 'max_window_length': 192}
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# [transformers] RobertaForTokenClassification LOAD REPORT from: vinai/phobert-base-v2
# Key                       | Status     |
# --------------------------+------------+-
# lm_head.bias              | UNEXPECTED |
# lm_head.dense.weight      | UNEXPECTED |
# lm_head.layer_norm.bias   | UNEXPECTED |
# lm_head.dense.bias        | UNEXPECTED |
# lm_head.layer_norm.weight | UNEXPECTED |
# classifier.bias           | MISSING    |
# classifier.weight         | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# 2026-08-09 22:34:11 | INFO    | src.models.phobert | Loaded vinai/phobert-base-v2 @ fb76b7e1f77f (134.4M parameters, num_labels=4)
# 2026-08-09 22:34:11 | INFO    | src.training.losses | Loss: CrossEntropyLoss(weight_mode=inverse, weights=[0.2744, 5.4164, 6.7058, 44.9985], ignore_index=-100)
# 2026-08-09 22:34:11 | INFO    | src.training.optimizer | AdamW(lr=3e-05, weight_decay=0.01, betas=(0.9, 0.999), eps=1e-08) — 134,289,408 decayed / 121,348 not decayed params
# 2026-08-09 22:34:11 | INFO    | src.training.scheduler | Scheduler: linear warmup+decay (1191 warmup / 11910 total optimizer steps, ratio=0.10)
#
# Model parameters      : 134,410,756 (134.4M)
# Train windows         : 38,111
# Validation windows    : 15,243
# Micro-batches / epoch : 9,528
# Optimizer steps/epoch : 2,382 (accumulation = 4, effective batch = 16)
# Mixed precision (fp16): True

# %%
result = trainer.fit()

print("\n" + "=" * 78)
print(f"TRAINING FINISHED — best epoch {result.best_epoch}, "
      f"validation {MONITOR_METRIC} = {result.best_score:.6f}")
print(f"Total time: {result.total_seconds / 60:.1f} min")
print("=" * 78)
# Out:
# 2026-08-09 22:34:11 | INFO    | src.training.trainer_base | === E3: training for 5 epoch(s) on cuda (AMP=True) ===
# E3 epoch 1 train:   0%|          | 0/9528 [00:00<?, ?it/s]
# 2026-08-09 22:34:36 | INFO    | src.training.trainer_phobert | epoch 1 step 500/9528 — loss 1.3077 (lr=3.15e-06)
# 2026-08-09 22:35:00 | INFO    | src.training.trainer_phobert | epoch 1 step 1000/9528 — loss 1.1037 (lr=6.30e-06)
# 2026-08-09 22:35:24 | INFO    | src.training.trainer_phobert | epoch 1 step 1500/9528 — loss 0.9156 (lr=9.45e-06)
# 2026-08-09 22:35:51 | INFO    | src.training.trainer_phobert | epoch 1 step 2000/9528 — loss 0.8006 (lr=1.26e-05)
# 2026-08-09 22:36:15 | INFO    | src.training.trainer_phobert | epoch 1 step 2500/9528 — loss 0.7251 (lr=1.57e-05)
# 2026-08-09 22:36:39 | INFO    | src.training.trainer_phobert | epoch 1 step 3000/9528 — loss 0.6685 (lr=1.89e-05)
# 2026-08-09 22:37:03 | INFO    | src.training.trainer_phobert | epoch 1 step 3500/9528 — loss 0.6279 (lr=2.20e-05)
# 2026-08-09 22:37:27 | INFO    | src.training.trainer_phobert | epoch 1 step 4000/9528 — loss 0.5959 (lr=2.52e-05)
# 2026-08-09 22:37:51 | INFO    | src.training.trainer_phobert | epoch 1 step 4500/9528 — loss 0.5698 (lr=2.83e-05)
# 2026-08-09 22:38:15 | INFO    | src.training.trainer_phobert | epoch 1 step 5000/9528 — loss 0.5481 (lr=2.98e-05)
# 2026-08-09 22:38:40 | INFO    | src.training.trainer_phobert | epoch 1 step 5500/9528 — loss 0.5299 (lr=2.95e-05)
# 2026-08-09 22:39:04 | INFO    | src.training.trainer_phobert | epoch 1 step 6000/9528 — loss 0.5143 (lr=2.91e-05)
# 2026-08-09 22:39:28 | INFO    | src.training.trainer_phobert | epoch 1 step 6500/9528 — loss 0.5010 (lr=2.88e-05)
# 2026-08-09 22:39:53 | INFO    | src.training.trainer_phobert | epoch 1 step 7000/9528 — loss 0.4885 (lr=2.84e-05)
# 2026-08-09 22:40:17 | INFO    | src.training.trainer_phobert | epoch 1 step 7500/9528 — loss 0.4772 (lr=2.81e-05)
# 2026-08-09 22:40:41 | INFO    | src.training.trainer_phobert | epoch 1 step 8000/9528 — loss 0.4677 (lr=2.77e-05)
# 2026-08-09 22:41:05 | INFO    | src.training.trainer_phobert | epoch 1 step 8500/9528 — loss 0.4593 (lr=2.74e-05)
# 2026-08-09 22:41:29 | INFO    | src.training.trainer_phobert | epoch 1 step 9000/9528 — loss 0.4517 (lr=2.70e-05)
# 2026-08-09 22:41:53 | INFO    | src.training.trainer_phobert | epoch 1 step 9500/9528 — loss 0.4446 (lr=2.67e-05)
# E3 epoch 1 validation:   0%|          | 0/1906 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-08-09 22:42:27 | INFO    | src.training.checkpointing | Epoch 1: new best punctuation_macro_f1=0.642513 (was -inf) — checkpoint written to outputs\checkpoints\E3
#
# [E3] epoch 1/5 (8.3 min) — train_loss=0.4442 val_loss=0.2968 val_PUNCT_F1=0.6425  <-- new best
# label       precision    recall        f1     support
# -----------------------------------------------------
# O              0.9982    0.9165    0.9556   1,800,593
# COMMA          0.3784    0.8456    0.5228      91,818
# PERIOD         0.6431    0.8585    0.7354      74,008
# QUESTION       0.5158    0.9531    0.6694      10,987
# -----------------------------------------------------
# accuracy       0.9112
# macro F1       0.7208   (all 4 classes)
# PUNCT-F1       0.6425   <-- model selection metric (COMMA/PERIOD/QUESTION)
# E3 epoch 2 train:   0%|          | 0/9528 [00:00<?, ?it/s]
# 2026-08-09 22:42:51 | INFO    | src.training.trainer_phobert | epoch 2 step 500/9528 — loss 0.2816 (lr=2.63e-05)
# 2026-08-09 22:43:15 | INFO    | src.training.trainer_phobert | epoch 2 step 1000/9528 — loss 0.2854 (lr=2.60e-05)
# 2026-08-09 22:43:39 | INFO    | src.training.trainer_phobert | epoch 2 step 1500/9528 — loss 0.2869 (lr=2.56e-05)
# 2026-08-09 22:44:03 | INFO    | src.training.trainer_phobert | epoch 2 step 2000/9528 — loss 0.2847 (lr=2.53e-05)
# 2026-08-09 22:44:27 | INFO    | src.training.trainer_phobert | epoch 2 step 2500/9528 — loss 0.2847 (lr=2.49e-05)
# 2026-08-09 22:44:51 | INFO    | src.training.trainer_phobert | epoch 2 step 3000/9528 — loss 0.2834 (lr=2.46e-05)
# 2026-08-09 22:45:15 | INFO    | src.training.trainer_phobert | epoch 2 step 3500/9528 — loss 0.2829 (lr=2.42e-05)
# 2026-08-09 22:45:39 | INFO    | src.training.trainer_phobert | epoch 2 step 4000/9528 — loss 0.2828 (lr=2.39e-05)
# 2026-08-09 22:46:03 | INFO    | src.training.trainer_phobert | epoch 2 step 4500/9528 — loss 0.2827 (lr=2.35e-05)
# 2026-08-09 22:46:28 | INFO    | src.training.trainer_phobert | epoch 2 step 5000/9528 — loss 0.2827 (lr=2.32e-05)
# 2026-08-09 22:46:52 | INFO    | src.training.trainer_phobert | epoch 2 step 5500/9528 — loss 0.2825 (lr=2.28e-05)
# 2026-08-09 22:47:17 | INFO    | src.training.trainer_phobert | epoch 2 step 6000/9528 — loss 0.2819 (lr=2.25e-05)
# 2026-08-09 22:47:41 | INFO    | src.training.trainer_phobert | epoch 2 step 6500/9528 — loss 0.2810 (lr=2.21e-05)
# 2026-08-09 22:48:05 | INFO    | src.training.trainer_phobert | epoch 2 step 7000/9528 — loss 0.2804 (lr=2.18e-05)
# 2026-08-09 22:48:29 | INFO    | src.training.trainer_phobert | epoch 2 step 7500/9528 — loss 0.2798 (lr=2.14e-05)
# 2026-08-09 22:48:53 | INFO    | src.training.trainer_phobert | epoch 2 step 8000/9528 — loss 0.2799 (lr=2.11e-05)
# 2026-08-09 22:49:17 | INFO    | src.training.trainer_phobert | epoch 2 step 8500/9528 — loss 0.2799 (lr=2.07e-05)
# 2026-08-09 22:49:41 | INFO    | src.training.trainer_phobert | epoch 2 step 9000/9528 — loss 0.2795 (lr=2.04e-05)
# 2026-08-09 22:50:05 | INFO    | src.training.trainer_phobert | epoch 2 step 9500/9528 — loss 0.2789 (lr=2.00e-05)
# E3 epoch 2 validation:   0%|          | 0/1906 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-08-09 22:50:39 | INFO    | src.training.checkpointing | Epoch 2: new best punctuation_macro_f1=0.679404 (was 0.642513) — checkpoint written to outputs\checkpoints\E3
#
# [E3] epoch 2/5 (8.2 min) — train_loss=0.2788 val_loss=0.2862 val_PUNCT_F1=0.6794  <-- new best
# label       precision    recall        f1     support
# -----------------------------------------------------
# O              0.9977    0.9354    0.9656   1,800,593
# COMMA          0.4471    0.8510    0.5862      91,818
# PERIOD         0.6648    0.8602    0.7500      74,008
# QUESTION       0.5574    0.9479    0.7020      10,987
# -----------------------------------------------------
# accuracy       0.9288
# macro F1       0.7509   (all 4 classes)
# PUNCT-F1       0.6794   <-- model selection metric (COMMA/PERIOD/QUESTION)
# E3 epoch 3 train:   0%|          | 0/9528 [00:00<?, ?it/s]
# 2026-08-09 22:51:03 | INFO    | src.training.trainer_phobert | epoch 3 step 500/9528 — loss 0.2417 (lr=1.97e-05)
# 2026-08-09 22:51:28 | INFO    | src.training.trainer_phobert | epoch 3 step 1000/9528 — loss 0.2399 (lr=1.93e-05)
# 2026-08-09 22:51:52 | INFO    | src.training.trainer_phobert | epoch 3 step 1500/9528 — loss 0.2403 (lr=1.90e-05)
# 2026-08-09 22:52:16 | INFO    | src.training.trainer_phobert | epoch 3 step 2000/9528 — loss 0.2409 (lr=1.86e-05)
# 2026-08-09 22:52:40 | INFO    | src.training.trainer_phobert | epoch 3 step 2500/9528 — loss 0.2404 (lr=1.83e-05)
# 2026-08-09 22:53:04 | INFO    | src.training.trainer_phobert | epoch 3 step 3000/9528 — loss 0.2404 (lr=1.79e-05)
# 2026-08-09 22:53:28 | INFO    | src.training.trainer_phobert | epoch 3 step 3500/9528 — loss 0.2403 (lr=1.76e-05)
# 2026-08-09 22:53:52 | INFO    | src.training.trainer_phobert | epoch 3 step 4000/9528 — loss 0.2404 (lr=1.72e-05)
# 2026-08-09 22:54:16 | INFO    | src.training.trainer_phobert | epoch 3 step 4500/9528 — loss 0.2401 (lr=1.69e-05)
# 2026-08-09 22:54:41 | INFO    | src.training.trainer_phobert | epoch 3 step 5000/9528 — loss 0.2403 (lr=1.65e-05)
# 2026-08-09 22:55:05 | INFO    | src.training.trainer_phobert | epoch 3 step 5500/9528 — loss 0.2401 (lr=1.62e-05)
# 2026-08-09 22:55:29 | INFO    | src.training.trainer_phobert | epoch 3 step 6000/9528 — loss 0.2404 (lr=1.58e-05)
# 2026-08-09 22:55:54 | INFO    | src.training.trainer_phobert | epoch 3 step 6500/9528 — loss 0.2398 (lr=1.55e-05)
# 2026-08-09 22:56:18 | INFO    | src.training.trainer_phobert | epoch 3 step 7000/9528 — loss 0.2400 (lr=1.51e-05)
# 2026-08-09 22:56:42 | INFO    | src.training.trainer_phobert | epoch 3 step 7500/9528 — loss 0.2398 (lr=1.48e-05)
# 2026-08-09 22:57:06 | INFO    | src.training.trainer_phobert | epoch 3 step 8000/9528 — loss 0.2395 (lr=1.44e-05)
# 2026-08-09 22:57:30 | INFO    | src.training.trainer_phobert | epoch 3 step 8500/9528 — loss 0.2396 (lr=1.41e-05)
# 2026-08-09 22:57:54 | INFO    | src.training.trainer_phobert | epoch 3 step 9000/9528 — loss 0.2395 (lr=1.37e-05)
# 2026-08-09 22:58:18 | INFO    | src.training.trainer_phobert | epoch 3 step 9500/9528 — loss 0.2395 (lr=1.34e-05)
# E3 epoch 3 validation:   0%|          | 0/1906 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-08-09 22:58:52 | INFO    | src.training.checkpointing | Epoch 3: new best punctuation_macro_f1=0.691703 (was 0.679404) — checkpoint written to outputs\checkpoints\E3
#
# [E3] epoch 3/5 (8.2 min) — train_loss=0.2394 val_loss=0.2821 val_PUNCT_F1=0.6917  <-- new best
# label       precision    recall        f1     support
# -----------------------------------------------------
# O              0.9971    0.9455    0.9706   1,800,593
# COMMA          0.4926    0.8345    0.6195      91,818
# PERIOD         0.6752    0.8674    0.7593      74,008
# QUESTION       0.5459    0.9610    0.6963      10,987
# -----------------------------------------------------
# accuracy       0.9375
# macro F1       0.7614   (all 4 classes)
# PUNCT-F1       0.6917   <-- model selection metric (COMMA/PERIOD/QUESTION)
# E3 epoch 4 train:   0%|          | 0/9528 [00:00<?, ?it/s]
# 2026-08-09 22:59:17 | INFO    | src.training.trainer_phobert | epoch 4 step 500/9528 — loss 0.2105 (lr=1.30e-05)
# 2026-08-09 22:59:41 | INFO    | src.training.trainer_phobert | epoch 4 step 1000/9528 — loss 0.2124 (lr=1.26e-05)
# 2026-08-09 23:00:05 | INFO    | src.training.trainer_phobert | epoch 4 step 1500/9528 — loss 0.2142 (lr=1.23e-05)
# 2026-08-09 23:00:29 | INFO    | src.training.trainer_phobert | epoch 4 step 2000/9528 — loss 0.2125 (lr=1.19e-05)
# 2026-08-09 23:00:53 | INFO    | src.training.trainer_phobert | epoch 4 step 2500/9528 — loss 0.2128 (lr=1.16e-05)
# 2026-08-09 23:01:17 | INFO    | src.training.trainer_phobert | epoch 4 step 3000/9528 — loss 0.2112 (lr=1.12e-05)
# 2026-08-09 23:01:41 | INFO    | src.training.trainer_phobert | epoch 4 step 3500/9528 — loss 0.2117 (lr=1.09e-05)
# 2026-08-09 23:02:05 | INFO    | src.training.trainer_phobert | epoch 4 step 4000/9528 — loss 0.2117 (lr=1.05e-05)
# 2026-08-09 23:02:29 | INFO    | src.training.trainer_phobert | epoch 4 step 4500/9528 — loss 0.2120 (lr=1.02e-05)
# 2026-08-09 23:02:54 | INFO    | src.training.trainer_phobert | epoch 4 step 5000/9528 — loss 0.2124 (lr=9.83e-06)
# 2026-08-09 23:03:18 | INFO    | src.training.trainer_phobert | epoch 4 step 5500/9528 — loss 0.2124 (lr=9.49e-06)
# 2026-08-09 23:03:42 | INFO    | src.training.trainer_phobert | epoch 4 step 6000/9528 — loss 0.2121 (lr=9.14e-06)
# 2026-08-09 23:04:07 | INFO    | src.training.trainer_phobert | epoch 4 step 6500/9528 — loss 0.2118 (lr=8.79e-06)
# 2026-08-09 23:04:31 | INFO    | src.training.trainer_phobert | epoch 4 step 7000/9528 — loss 0.2125 (lr=8.44e-06)
# 2026-08-09 23:04:55 | INFO    | src.training.trainer_phobert | epoch 4 step 7500/9528 — loss 0.2121 (lr=8.09e-06)
# 2026-08-09 23:05:19 | INFO    | src.training.trainer_phobert | epoch 4 step 8000/9528 — loss 0.2120 (lr=7.74e-06)
# 2026-08-09 23:05:43 | INFO    | src.training.trainer_phobert | epoch 4 step 8500/9528 — loss 0.2120 (lr=7.39e-06)
# 2026-08-09 23:06:07 | INFO    | src.training.trainer_phobert | epoch 4 step 9000/9528 — loss 0.2121 (lr=7.04e-06)
# 2026-08-09 23:06:31 | INFO    | src.training.trainer_phobert | epoch 4 step 9500/9528 — loss 0.2119 (lr=6.69e-06)
# E3 epoch 4 validation:   0%|          | 0/1906 [00:00<?, ?it/s]
# 2026-08-09 23:07:05 | INFO    | src.training.checkpointing | Epoch 4: punctuation_macro_f1=0.690875 did not beat best=0.691703 (epoch 3) — not saving
#
# [E3] epoch 4/5 (8.2 min) — train_loss=0.2118 val_loss=0.2930 val_PUNCT_F1=0.6909
# label       precision    recall        f1     support
# -----------------------------------------------------
# O              0.9975    0.9423    0.9691   1,800,593
# COMMA          0.4836    0.8256    0.6099      91,818
# PERIOD         0.6488    0.8896    0.7503      74,008
# QUESTION       0.5706    0.9478    0.7124      10,987
# -----------------------------------------------------
# accuracy       0.9349
# macro F1       0.7604   (all 4 classes)
# PUNCT-F1       0.6909   <-- model selection metric (COMMA/PERIOD/QUESTION)
# E3 epoch 5 train:   0%|          | 0/9528 [00:00<?, ?it/s]
# 2026-08-09 23:07:29 | INFO    | src.training.trainer_phobert | epoch 5 step 500/9528 — loss 0.1919 (lr=6.32e-06)
# 2026-08-09 23:07:53 | INFO    | src.training.trainer_phobert | epoch 5 step 1000/9528 — loss 0.1891 (lr=5.97e-06)
# 2026-08-09 23:08:17 | INFO    | src.training.trainer_phobert | epoch 5 step 1500/9528 — loss 0.1905 (lr=5.62e-06)
# 2026-08-09 23:08:41 | INFO    | src.training.trainer_phobert | epoch 5 step 2000/9528 — loss 0.1905 (lr=5.27e-06)
# 2026-08-09 23:09:05 | INFO    | src.training.trainer_phobert | epoch 5 step 2500/9528 — loss 0.1908 (lr=4.92e-06)
# 2026-08-09 23:09:29 | INFO    | src.training.trainer_phobert | epoch 5 step 3000/9528 — loss 0.1910 (lr=4.57e-06)
# 2026-08-09 23:09:53 | INFO    | src.training.trainer_phobert | epoch 5 step 3500/9528 — loss 0.1918 (lr=4.22e-06)
# 2026-08-09 23:10:18 | INFO    | src.training.trainer_phobert | epoch 5 step 4000/9528 — loss 0.1919 (lr=3.87e-06)
# 2026-08-09 23:10:42 | INFO    | src.training.trainer_phobert | epoch 5 step 4500/9528 — loss 0.1916 (lr=3.52e-06)
# 2026-08-09 23:11:06 | INFO    | src.training.trainer_phobert | epoch 5 step 5000/9528 — loss 0.1918 (lr=3.17e-06)
# 2026-08-09 23:11:31 | INFO    | src.training.trainer_phobert | epoch 5 step 5500/9528 — loss 0.1923 (lr=2.82e-06)
# 2026-08-09 23:11:55 | INFO    | src.training.trainer_phobert | epoch 5 step 6000/9528 — loss 0.1925 (lr=2.47e-06)
# 2026-08-09 23:12:19 | INFO    | src.training.trainer_phobert | epoch 5 step 6500/9528 — loss 0.1926 (lr=2.12e-06)
# 2026-08-09 23:12:43 | INFO    | src.training.trainer_phobert | epoch 5 step 7000/9528 — loss 0.1922 (lr=1.77e-06)
# 2026-08-09 23:13:07 | INFO    | src.training.trainer_phobert | epoch 5 step 7500/9528 — loss 0.1924 (lr=1.42e-06)
# 2026-08-09 23:13:31 | INFO    | src.training.trainer_phobert | epoch 5 step 8000/9528 — loss 0.1922 (lr=1.07e-06)
# 2026-08-09 23:13:55 | INFO    | src.training.trainer_phobert | epoch 5 step 8500/9528 — loss 0.1920 (lr=7.19e-07)
# 2026-08-09 23:14:19 | INFO    | src.training.trainer_phobert | epoch 5 step 9000/9528 — loss 0.1917 (lr=3.69e-07)
# 2026-08-09 23:14:43 | INFO    | src.training.trainer_phobert | epoch 5 step 9500/9528 — loss 0.1918 (lr=1.96e-08)
# E3 epoch 5 validation:   0%|          | 0/1906 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-08-09 23:15:17 | INFO    | src.training.checkpointing | Epoch 5: new best punctuation_macro_f1=0.695324 (was 0.691703) — checkpoint written to outputs\checkpoints\E3
#
# [E3] epoch 5/5 (8.2 min) — train_loss=0.1917 val_loss=0.3022 val_PUNCT_F1=0.6953  <-- new best
# label       precision    recall        f1     support
# -----------------------------------------------------
# O              0.9975    0.9431    0.9695   1,800,593
# COMMA          0.4820    0.8389    0.6122      91,818
# PERIOD         0.6693    0.8764    0.7590      74,008
# QUESTION       0.5739    0.9472    0.7147      10,987
# -----------------------------------------------------
# accuracy       0.9358
# macro F1       0.7639   (all 4 classes)
# PUNCT-F1       0.6953   <-- model selection metric (COMMA/PERIOD/QUESTION)
#
# ==============================================================================
# TRAINING FINISHED — best epoch 5, validation punctuation_macro_f1 = 0.695324
# Total time: 41.1 min
# ==============================================================================

# %% [markdown]
# # 8. Validation
#
# Validation chạy **sau mỗi epoch**, trên toàn bộ `validation.jsonl` (tập `dev`
# chính thức của JointCapPunc). Chỉ những vị trí có nhãn khác `-100` được tính —
# tức là đúng một vị trí cho mỗi từ.
#
# **Metric chính để chọn checkpoint: Punctuation Macro-F1**
#
# $$\text{PUNCT-F1} = \frac{F1_{COMMA} + F1_{PERIOD} + F1_{QUESTION}}{3}$$
#
# **Vì sao loại `O` ra khỏi metric chính?** Vì `O` chiếm 91% dữ liệu. Một mô hình
# đoán `O` cho mọi từ đạt:
#
# * accuracy = **0.911** (nghe rất cao),
# * macro-F1 4 lớp = **0.238** (vẫn khác 0),
# * Punctuation Macro-F1 = **0.000** ← chỉ số duy nhất nói đúng sự thật.
#
# **Vì sao macro chứ không micro?** `QUESTION` chỉ chiếm 0.56% số token. Micro-F1
# lấy trung bình theo số lượng nên `QUESTION` gần như vô hình; macro cho ba lớp
# trọng số bằng nhau, buộc mô hình phải làm tốt cả lớp hiếm nhất.
#
# Các chỉ số khác (accuracy, macro-F1 4 lớp, micro-F1, precision/recall từng lớp)
# vẫn được ghi lại đầy đủ để phân tích, nhưng **không** dùng để chọn checkpoint.

# %%
best_metrics = trainer.checkpoints.best_metrics
artifacts    = trainer.artifacts

artifacts.write_best_validation(best_metrics, best_epoch=result.best_epoch)
artifacts.write_per_class(best_metrics)
artifacts.write_confusion_matrix(best_metrics)
artifacts.write_history()

print(f"Best epoch                 : {result.best_epoch}")
print(f"Validation PUNCT Macro-F1  : {best_metrics['punctuation_macro_f1']:.6f}")
print(f"Validation accuracy        : {best_metrics['accuracy']:.6f}")
print(f"Validation macro-F1 (4 cls): {best_metrics['macro_f1']:.6f}")
print(f"Supervised tokens scored   : {best_metrics['num_evaluated_tokens']:,}")
# Out:
# Best epoch                 : 5
# Validation PUNCT Macro-F1  : 0.695324
# Validation accuracy        : 0.935833
# Validation macro-F1 (4 cls): 0.763878
# Supervised tokens scored   : 1,977,406

# %% [markdown]
# # 9. Training Curves
#
# Hai biểu đồ:
#
# * **trái** — train loss và validation loss theo epoch. Nếu train loss tiếp tục
#   giảm trong khi validation loss đi lên thì mô hình bắt đầu overfit;
# * **phải** — validation Punctuation Macro-F1 (đường quyết định) cùng macro-F1
#   4 lớp. Vòng tròn đỏ đánh dấu epoch tốt nhất, chính là epoch được lưu
#   checkpoint.
#
# Khoảng cách giữa hai đường F1 cho thấy lớp `O` "kéo" macro-F1 lên bao nhiêu —
# đó là lý do ta không dùng macro-F1 4 lớp để chọn model.

# %%
# %matplotlib inline
curve_path = artifacts.plot_training_curves(show=True)
print("Saved:", curve_path)

history_df = pd.read_csv(artifacts.path("training_history.csv"))
display(history_df[[
    "epoch", "train_loss", "val_loss", "val_accuracy",
    "val_punctuation_macro_f1", "val_f1_COMMA", "val_f1_PERIOD", "val_f1_QUESTION",
    "learning_rate", "epoch_seconds", "is_best",
]].round(5))
# Out:
# Saved: outputs\experiments\E3\training_curves.png
#    epoch  train_loss  val_loss  val_accuracy  val_punctuation_macro_f1  \
# 0      1     0.44415   0.29685       0.91122                   0.64251
# 1      2     0.27882   0.28617       0.92878                   0.67940
# 2      3     0.23940   0.28214       0.93754                   0.69170
# 3      4     0.21176   0.29302       0.93495                   0.69088
# 4      5     0.19167   0.30222       0.93583                   0.69532
#
#    val_f1_COMMA  val_f1_PERIOD  val_f1_QUESTION  learning_rate  epoch_seconds  \
# 0       0.52278        0.73536          0.66939        0.00000         495.07
# 1       0.58623        0.75000          0.70198        0.00003         492.70
# 2       0.61951        0.75930          0.69630        0.00002         493.12
# 3       0.60992        0.75034          0.71236        0.00001         492.57
# 4       0.61224        0.75899          0.71474        0.00001         492.43
#
#    is_best
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1

# %% [markdown]
# # 10. Best Checkpoint
#
# Chỉ **một** checkpoint được giữ: epoch có validation Punctuation Macro-F1 cao
# nhất. Khi có epoch tốt hơn, thư mục được ghi đè — nên không bao giờ nhầm lẫn
# giữa "checkpoint cuối cùng" và "checkpoint tốt nhất".
#
# `checkpoint_metadata.json` đi kèm ghi lại toàn bộ ngữ cảnh: experiment id, tên
# và revision của model, bảng nhãn, cấu hình huấn luyện, epoch tốt nhất, điểm
# validation, hash của dữ liệu, seed, và phiên bản Python / PyTorch /
# Transformers / CUDA cùng tên GPU. Nhờ vậy Phase 2 (và người chấm) có thể truy
# ngược mọi con số về đúng dữ liệu và môi trường đã tạo ra nó.

# %%
ckpt_dir = Path(trainer.checkpoints.checkpoint_dir)
meta     = read_json(ckpt_dir / "checkpoint_metadata.json")

print(f"Checkpoint directory: {ckpt_dir.relative_to(PROJECT_ROOT)}\n")
for f in sorted(ckpt_dir.iterdir()):
    print(f"  {f.name:<32}{f.stat().st_size / 1024:>12,.0f} KB")

print("\nMetadata:")
for key in ("experiment_id", "model_type", "model_name", "model_revision",
            "monitor_metric", "best_epoch", "best_score", "seed",
            "python_version", "torch_version", "transformers_version",
            "cuda_version", "gpu_name"):
    print(f"  {key:<22}: {meta.get(key)}")
print(f"  {'label2id':<22}: {meta.get('label2id')}")
print(f"  {'train content_sha256':<22}: {meta['data_hashes']['train']['content_sha256'][:32]}…")
# Out:
# Checkpoint directory: outputs\checkpoints\E3
#
#   .gitkeep                                   0 KB
#   added_tokens.json                          0 KB
#   bpe.codes                              1,109 KB
#   checkpoint_metadata.json                   6 KB
#   config.json                                1 KB
#   model.safetensors                    525,065 KB
#   tokenizer_config.json                      1 KB
#   vocab.txt                                874 KB
#
# Metadata:
#   experiment_id         : E3
#   model_type            : phobert
#   model_name            : vinai/phobert-base-v2
#   model_revision        : fb76b7e1f77fa19bc4870e2ad956876f7c81c53f
#   monitor_metric        : punctuation_macro_f1
#   best_epoch            : 5
#   best_score            : 0.6953238496529216
#   seed                  : 42
#   python_version        : 3.12.4
#   torch_version         : 2.13.0+cu126
#   transformers_version  : 5.14.1
#   cuda_version          : 12.6
#   gpu_name              : NVIDIA GeForce RTX 4060 Laptop GPU
#   label2id              : {'O': 0, 'COMMA': 1, 'PERIOD': 2, 'QUESTION': 3}
#   train content_sha256  : 138983bc2761546f13c9520d5339b2ea…

# %% [markdown]
# # 11. Validation Results
#
# Bảng dưới là kết quả của **epoch tốt nhất** trên toàn bộ validation.
#
# Cách đọc confusion matrix: hàng = nhãn đúng, cột = nhãn mô hình dự đoán. Ô
# `gold_PERIOD / pred_O` là số lần mô hình *bỏ sót* một dấu chấm; ô
# `gold_O / pred_COMMA` là số lần mô hình *thêm thừa* một dấu phẩy. Hai kiểu lỗi
# này có ý nghĩa rất khác nhau khi đánh giá chất lượng thực tế.

# %%
print(format_metrics_table(best_metrics))

print("\nConfusion matrix (hàng = gold, cột = predicted)")
cm_df = pd.DataFrame(
    best_metrics["confusion_matrix"],
    index=[f"gold_{l}" for l in LABELS],
    columns=[f"pred_{l}" for l in LABELS],
)
display(cm_df)

print("Tỉ lệ theo hàng (recall của mỗi lớp nằm trên đường chéo):")
display((cm_df.div(cm_df.sum(axis=1), axis=0) * 100).round(2))
# Out:
# label       precision    recall        f1     support
# -----------------------------------------------------
# O              0.9975    0.9431    0.9695   1,800,593
# COMMA          0.4820    0.8389    0.6122      91,818
# PERIOD         0.6693    0.8764    0.7590      74,008
# QUESTION       0.5739    0.9472    0.7147      10,987
# -----------------------------------------------------
# accuracy       0.9358
# macro F1       0.7639   (all 4 classes)
# PUNCT-F1       0.6953   <-- model selection metric (COMMA/PERIOD/QUESTION)
#
# Confusion matrix (hàng = gold, cột = predicted)
#                 pred_O  pred_COMMA  pred_PERIOD  pred_QUESTION
# gold_O         1698226       76171        21432           4764
# gold_COMMA        3486       77027        10249           1056
# gold_PERIOD        772        6467        64862           1907
# gold_QUESTION       74         140          366          10407
# Tỉ lệ theo hàng (recall của mỗi lớp nằm trên đường chéo):
#                pred_O  pred_COMMA  pred_PERIOD  pred_QUESTION
# gold_O          94.31        4.23         1.19           0.26
# gold_COMMA       3.80       83.89        11.16           1.15
# gold_PERIOD      1.04        8.74        87.64           2.58
# gold_QUESTION    0.67        1.27         3.33          94.72

# %% [markdown]
# # 12. Per-Class Results
#
# * **precision** = trong các từ mô hình gán nhãn X, bao nhiêu phần trăm đúng →
#   đo mức độ "thêm dấu câu thừa";
# * **recall** = trong các từ thực sự mang nhãn X, mô hình bắt được bao nhiêu →
#   đo mức độ "bỏ sót dấu câu";
# * **F1** = trung bình điều hoà của hai chỉ số trên;
# * **support** = số từ thực sự mang nhãn đó trong validation.
#
# `QUESTION` là lớp khó nhất (chỉ ~0.56% dữ liệu) và là nơi khác biệt giữa E2, E3,
# E4 sẽ lộ ra rõ nhất. Khi so sánh 4 thí nghiệm ở Phase 2, hãy nhìn cả precision
# lẫn recall của lớp này chứ không chỉ nhìn F1 tổng.

# %%
per_class_df = pd.read_csv(artifacts.path("per_class_validation_metrics.csv"))
display(per_class_df)

pc = best_metrics["per_class"]
print("Punctuation Macro-F1 = mean of the three punctuation F1 scores:")
print(f"  F1_COMMA    = {pc['COMMA']['f1']:.6f}")
print(f"  F1_PERIOD   = {pc['PERIOD']['f1']:.6f}")
print(f"  F1_QUESTION = {pc['QUESTION']['f1']:.6f}")
print(f"  ---------------------------")
print(f"  PUNCT-F1    = {best_metrics['punctuation_macro_f1']:.6f}")
# Out:
#                   label  precision    recall        f1    support         tp  \
# 0                     O   0.997456  0.943148  0.969542  1800593.0  1698226.0
# 1                 COMMA   0.482006  0.838910  0.612241    91818.0    77027.0
# 2                PERIOD   0.669308  0.876419  0.758988    74008.0    64862.0
# 3              QUESTION   0.573894  0.947210  0.714742    10987.0    10407.0
# 4  PUNCTUATION_MACRO_F1        NaN       NaN  0.695324        NaN        NaN
# 5  MACRO_F1_ALL_CLASSES        NaN       NaN  0.763878        NaN        NaN
# 6              ACCURACY        NaN       NaN  0.935833        NaN        NaN
#
#         fp        fn
# 0   4332.0  102367.0
# 1  82778.0   14791.0
# 2  32047.0    9146.0
# 3   7727.0     580.0
# 4      NaN       NaN
# 5      NaN       NaN
# 6      NaN       NaN
# Punctuation Macro-F1 = mean of the three punctuation F1 scores:
#   F1_COMMA    = 0.612241
#   F1_PERIOD   = 0.758988
#   F1_QUESTION = 0.714742
#   ---------------------------
#   PUNCT-F1    = 0.695324

# %% [markdown]
# # 13. Một số prediction sample trên VALIDATION
#
# Phần này nạp lại **checkpoint tốt nhất** (chứ không dùng model của epoch cuối)
# rồi chạy dự đoán trên vài ví dụ đầu của validation, để so sánh trực tiếp câu
# gold và câu mô hình sinh ra.
#
# Viết hoa đầu câu chỉ là bước hiển thị cho dễ đọc — mô hình **không** dự đoán
# viết hoa, nó chỉ dự đoán dấu câu. (JointCapPunc có cột capitalization nhưng đồ
# án này không dùng.)
#
# Đây vẫn là dữ liệu **validation** — không phải test.

# %%
best_model, _ = load_model_from_checkpoint(ckpt_dir, device=device)

from torch.utils.data import DataLoader
from src.data.dataset import PhoBERTDataset, collate_phobert

sample_examples = validation_examples[:24]
sample_loader = DataLoader(
    PhoBERTDataset(sample_examples, encoder, log_every=0),
    batch_size=8, shuffle=False,
    collate_fn=lambda b: collate_phobert(b, pad_id=encoder.pad_id),
)

predictions = predict_word_labels(best_model, sample_loader, device=device, use_amp=trainer.use_amp)
rows = sample_predictions(best_model, sample_examples, predictions, n=8)

for r in rows[:5]:
    print(f"--- {r['id']}  ({r['num_words']} từ, token accuracy {r['token_accuracy']:.1%})")
    print(f"  input : {r['input_text'][:150]}")
    print(f"  gold  : {r['gold_text'][:150]}")
    print(f"  pred  : {r['predicted_text'][:150]}\n")

artifacts.write_sample_predictions(rows)
display(pd.DataFrame(rows)[["id", "num_words", "token_accuracy"]])
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# 2026-08-09 23:15:19 | INFO    | src.data.dataset | PhoBERT dataset ready: {'num_examples': 24, 'num_windows': 24, 'num_words': 3243, 'num_subwords': 3413, 'windows_per_example': 1.0, 'subwords_per_word': 1.0524, 'examples_split_into_multiple_windows': 0, 'max_window_length': 163}
# --- validation_000001  (136 từ, token accuracy 94.1%)
#   input : bác sĩ ơibụng của con bị đầy hơicon phải làm thế nào ạcon sợ quá chào em em đi ngoài thế nào em con đi ngoài bình thường ạ con đi khámbs bảo là không
#   gold  : Bác sĩ ơibụng của con bị đầy hơicon phải làm thế nào ạcon sợ quá. Chào em em đi ngoài thế nào em? Con đi ngoài bình thường ạ con đi khámbs bảo là khôn
#   pred  : Bác sĩ ơibụng của con bị đầy hơicon phải làm thế nào ạcon sợ quá? Chào em. Em đi ngoài thế nào em? Con đi ngoài bình thường ạ. Con đi khámbs bảo là kh
#
# --- validation_000002  (133 từ, token accuracy 96.2%)
#   input : vợ chồng em có quan hệ và hoạt động hơi mạnh ngày hôm sau em cảm thấy vùng bụng dưới bị xốn lấy tay sờ vào vùng kín thì cảm nhận được dây vòng dài hơn
#   gold  : Vợ chồng em có quan hệ và hoạt động hơi mạnh, ngày hôm sau em cảm thấy vùng bụng dưới bị xốn, lấy tay sờ vào vùng kín thì cảm nhận được dây vòng dài h
#   pred  : Vợ chồng em có quan hệ và hoạt động hơi mạnh. Ngày hôm sau em cảm thấy vùng bụng dưới bị xốn, lấy tay sờ vào vùng kín thì cảm nhận được dây vòng dài h
#
# --- validation_000003  (140 từ, token accuracy 92.9%)
#   input : bạn nên kiêng quan hệ vợ chồng 5-7 ngày cho đến khi mọi việc trở lại bình thường nếu còn thấy khó chịu thì nên khám phụ khoa để được kiểm tra thêm bạn
#   gold  : Bạn nên kiêng quan hệ vợ chồng 5-7 ngày cho đến khi mọi việc trở lại bình thường. Nếu còn thấy khó chịu thì nên khám phụ khoa để được kiểm tra thêm, b
#   pred  : Bạn nên kiêng quan hệ vợ chồng 5-7 ngày cho đến khi mọi việc trở lại bình thường. Nếu còn thấy khó chịu thì nên khám phụ khoa để được kiểm tra thêm bạ
#
# --- validation_000004  (133 từ, token accuracy 92.5%)
#   input : cháu thấy có quảng cáo thuốc kim đởm khang chữa sỏi mật thực hư là như thế nào ạ có thuốc hay cách nào chữa bệnh này ko ạ thực phẩm bảo vệ sức khỏe ch
#   gold  : Cháu thấy có quảng cáo thuốc kim đởm khang chữa sỏi mật. Thực hư là như thế nào ạ? Có thuốc hay cách nào chữa bệnh này ko ạ? Thực phẩm bảo vệ sức khỏe
#   pred  : Cháu thấy có quảng cáo thuốc kim đởm khang chữa sỏi mật thực hư là như thế nào ạ? Có thuốc hay cách nào chữa bệnh này ko ạ? Thực phẩm bảo vệ sức khỏe
#
# --- validation_000005  (141 từ, token accuracy 95.7%)
#   input : hạch bạch huyết sưng có thể do nhiều nguyên nhân thế nhưng vẫn cần đi khám để loại trừ nguy cơ hiv chào em không có dấu hiệu nào đặc hiệu cho nhiễm hi
#   gold  : Hạch bạch huyết sưng có thể do nhiều nguyên nhân, thế nhưng vẫn cần đi khám để loại trừ nguy cơ hiv. Chào em, không có dấu hiệu nào đặc hiệu cho nhiễm
#   pred  : Hạch bạch huyết sưng có thể do nhiều nguyên nhân, thế nhưng, vẫn cần đi khám để loại trừ nguy cơ hiv. Chào em, không có dấu hiệu nào đặc hiệu cho nhiễ
#                   id  num_words  token_accuracy
# 0  validation_000001        136        0.941176
# 1  validation_000002        133        0.962406
# 2  validation_000003        140        0.928571
# 3  validation_000004        133        0.924812
# 4  validation_000005        141        0.957447
# 5  validation_000006        130        0.984615
# 6  validation_000007        134        0.955224
# 7  validation_000008        148        0.952703

# %% [markdown]
# # 14. Artifact Paths
#
# Cell dưới ghi `experiment_summary.json` với **trạng thái `COMPLETED` và các con
# số thật vừa đo được**, rồi liệt kê toàn bộ file mà notebook này đã sinh ra.
#
# Trước khi chạy, file này mang trạng thái `NOT_YET_RUN` — dự án không bao giờ
# điền sẵn kết quả giả.

# %%
summary_path = artifacts.write_summary(
    model=config['model']['name'],
    weight_mode=config["loss"]["weight_mode"],
    best_epoch=result.best_epoch,
    best_score=result.best_score,
    checkpoint_path=ckpt_dir,
    extra={
        "best_validation_accuracy": best_metrics["accuracy"],
        "best_validation_macro_f1_all_classes": best_metrics["macro_f1"],
        "best_validation_f1_per_class": {
            lab: best_metrics["per_class"][lab]["f1"] for lab in LABELS
        },
        "total_training_seconds": round(result.total_seconds, 1),
        "evaluated_on": "validation.jsonl (official JointCapPunc dev split)",
        "test_split_used": False,
    },
)

print("Artifacts written by this notebook\n")
print(f"{'outputs/experiments/' + EXPERIMENT_ID:<45}")
for f in sorted(artifacts.dir.iterdir()):
    print(f"   {f.name:<42}{f.stat().st_size / 1024:>10,.1f} KB")
print(f"\n{'outputs/checkpoints/' + EXPERIMENT_ID:<45}")
for f in sorted(ckpt_dir.iterdir()):
    print(f"   {f.name:<42}{f.stat().st_size / 1024:>10,.1f} KB")

print("\nexperiment_summary.json:")
print(json.dumps(read_json(summary_path), indent=2, ensure_ascii=False))
# Out:
# 2026-08-09 23:15:19 | INFO    | src.training.artifacts | Experiment E3 COMPLETED: {'status': 'COMPLETED', 'experiment_id': 'E3', 'model': 'vinai/phobert-base-v2', 'weight_mode': 'inverse', 'best_epoch': 5, 'best_validation_punctuation_macro_f1': 0.6953238496529216, 'checkpoint_path': 'outputs/checkpoints/E3', 'monitor_metric': 'punctuation_macro_f1', 'num_epochs_completed': 5, 'completed_at_utc': '2026-08-09T16:15:19+00:00', 'best_validation_accuracy': 0.9358331066053203, 'best_validation_macro_f1_all_classes': 0.76387838532413, 'best_validation_f1_per_class': {'O': 0.9695419923377553, 'COMMA': 0.6122413292902478, 'PERIOD': 0.7589882808614707, 'QUESTION': 0.7147419388070464}, 'total_training_seconds': 2465.9, 'evaluated_on': 'validation.jsonl (official JointCapPunc dev split)', 'test_split_used': False}
# Artifacts written by this notebook
#
# outputs/experiments/E3
#    best_validation_metrics.json                     1.6 KB
#    config.json                                      3.3 KB
#    data_hashes.json                                 1.5 KB
#    environment.json                                 0.8 KB
#    experiment_summary.json                          0.8 KB
#    per_class_validation_metrics.csv                 0.4 KB
#    training_curves.png                             80.5 KB
#    training_history.csv                             1.5 KB
#    validation_confusion_matrix.csv                  0.2 KB
#    validation_sample_predictions.csv               18.6 KB
#
# outputs/checkpoints/E3
#    .gitkeep                                         0.0 KB
#    added_tokens.json                                0.0 KB
#    bpe.codes                                    1,108.6 KB
#    checkpoint_metadata.json                         6.2 KB
#    config.json                                      1.0 KB
#    model.safetensors                          525,065.4 KB
#    tokenizer_config.json                            1.2 KB
#    vocab.txt                                      874.3 KB
#
# experiment_summary.json:
# {
#   "status": "COMPLETED",
#   "experiment_id": "E3",
#   "model": "vinai/phobert-base-v2",
#   "weight_mode": "inverse",
#   "best_epoch": 5,
#   "best_validation_punctuation_macro_f1": 0.6953238496529216,
#   "checkpoint_path": "outputs/checkpoints/E3",
#   "monitor_metric": "punctuation_macro_f1",
#   "num_epochs_completed": 5,
#   "completed_at_utc": "2026-08-09T16:15:19+00:00",
#   "best_validation_accuracy": 0.9358331066053203,
#   "best_validation_macro_f1_all_classes": 0.76387838532413,
#   "best_validation_f1_per_class": {
#     "O": 0.9695419923377553,
#     "COMMA": 0.6122413292902478,
#     "PERIOD": 0.7589882808614707,
#     "QUESTION": 0.7147419388070464
#   },
#   "total_training_seconds": 2465.9,
#   "evaluated_on": "validation.jsonl (official JointCapPunc dev split)",
#   "test_split_used": false
# }

# %% [markdown]
# # 15. Experiment Conclusion
#
# Khi đọc kết quả E3, hãy trả lời trong báo cáo:
#
# 1. **Recall của `QUESTION` và `PERIOD` có tăng so với E2 không?** Đây là hiệu
#    ứng trực tiếp mà class weight nhắm tới.
# 2. **Precision có tụt không?** Trọng số 45× rất dễ khiến mô hình dự đoán dấu câu
#    tràn lan.
# 3. **PUNCT-F1 tổng cao hơn hay thấp hơn E2?** Chỉ số này mới là kết luận; tăng
#    recall mà mất precision nhiều hơn thì đây là một thay đổi tệ.
# 4. Ghi lại cả trường hợp E3 **thua** E2 — kết quả âm cũng là kết quả khoa học,
#    không được che giấu.
#
# ### Checklist sau khi chạy xong notebook này
#
# - [ ] `outputs/checkpoints/E3/` có checkpoint (`model.pt` hoặc `model.safetensors`) + `checkpoint_metadata.json`
# - [ ] `outputs/experiments/E3/experiment_summary.json` có `"status": "COMPLETED"`
# - [ ] `outputs/experiments/E3/best_validation_metrics.json` tồn tại
# - [ ] `outputs/experiments/E3/training_history.csv` có đủ số dòng bằng số epoch đã chạy
# - [ ] `outputs/experiments/E3/per_class_validation_metrics.csv` tồn tại
# - [ ] `outputs/experiments/E3/validation_confusion_matrix.csv` tồn tại
# - [ ] `outputs/experiments/E3/training_curves.png` tồn tại
#
# Cell cuối kiểm tra tự động những mục trên.
#
# ### Bước tiếp theo
#
# Chạy tiếp `notebooks/04_E4_PhoBERT_SqrtInverse.ipynb`.

# %%
expected = [
    artifacts.path("config.json"),
    artifacts.path("training_history.csv"),
    artifacts.path("best_validation_metrics.json"),
    artifacts.path("per_class_validation_metrics.csv"),
    artifacts.path("validation_confusion_matrix.csv"),
    artifacts.path("environment.json"),
    artifacts.path("data_hashes.json"),
    artifacts.path("experiment_summary.json"),
    artifacts.path("training_curves.png"),
    ckpt_dir / "checkpoint_metadata.json",
]
ok = True
for path in expected:
    exists = path.exists()
    ok &= exists
    print(f"  [{'OK  ' if exists else 'MISS'}] {path.relative_to(PROJECT_ROOT)}")

summary = read_json(artifacts.path("experiment_summary.json"))
status_ok = summary.get("status") == "COMPLETED"
print(f"\n  [{'OK  ' if status_ok else 'MISS'}] experiment_summary.json status = {summary.get('status')}")

print("\n" + "=" * 78)
if ok and status_ok:
    print(f"{EXPERIMENT_ID} COMPLETED — validation {MONITOR_METRIC} = "
          f"{summary['best_validation_punctuation_macro_f1']:.6f} at epoch "
          f"{summary['best_epoch']}")
    print("Test split was never loaded in this notebook.")
else:
    print(f"{EXPERIMENT_ID} INCOMPLETE — re-run the notebook from the top.")
print("=" * 78)
# Out:
#   [OK  ] outputs\experiments\E3\config.json
#   [OK  ] outputs\experiments\E3\training_history.csv
#   [OK  ] outputs\experiments\E3\best_validation_metrics.json
#   [OK  ] outputs\experiments\E3\per_class_validation_metrics.csv
#   [OK  ] outputs\experiments\E3\validation_confusion_matrix.csv
#   [OK  ] outputs\experiments\E3\environment.json
#   [OK  ] outputs\experiments\E3\data_hashes.json
#   [OK  ] outputs\experiments\E3\experiment_summary.json
#   [OK  ] outputs\experiments\E3\training_curves.png
#   [OK  ] outputs\checkpoints\E3\checkpoint_metadata.json
#
#   [OK  ] experiment_summary.json status = COMPLETED
#
# ==============================================================================
# E3 COMPLETED — validation punctuation_macro_f1 = 0.695324 at epoch 5
# Test split was never loaded in this notebook.
# ==============================================================================
